# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr1 = np.array([23, 4, 3, 23])

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
arr1.astype("float64")
# Out:
# array([23.,  4.,  3., 23.])

# %%
arr2 = np.array([1,2,3,4,5], dtype = "float32")

# %%
arr2.dtype
# Out:
# dtype('float32')

# %%
arr2.nbytes
# Out:
# 20

# %%
arr.nbytes
# Out:
# 32

# %%
arr1.nbytes
# Out:
# 32
