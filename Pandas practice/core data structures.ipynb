# %%
import pandas as pd

# %%
s1 = pd.Series([71, 84, 56, 23, 56, 98, 56])

# %%
s1
# Out:
# 0    71
# 1    84
# 2    56
# 3    23
# 4    56
# 5    98
# 6    56
# dtype: int64

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([71, 84, 56, 23, 56, 98, 56], index=["Mili", "siya", "ras", "man", "sam", "riya", "neha"])

# %%
s2
# Out:
# Mili    71
# siya    84
# ras     56
# man     23
# sam     56
# riya    98
# neha    56
# dtype: int64

# %%
s2["Mili"]
# Out:
# np.int64(71)

# %%
data = {
    "name" :["Mili", "Neha", "Riya"],
    "age": [20, 23, 21],
    "city": ["Pune", "Delhi", "Mumbai"]
    }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    name  age    city
# 0  Mili   20    Pune
# 1  Neha   23   Delhi
# 2  Riya   21  Mumbai

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')
