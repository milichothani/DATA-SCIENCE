# %%
import pandas as pd

# %%
df = pd.read_csv("data_cleaning_sample.csv")

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_values("Join Date")
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.sort_values("Join Date", ascending = False)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN

# %%
df.sort_values("Age")
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_values(["Age" , "Join Date"])
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2 = df.sort_values(["Age", "Join Date"]).copy()

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2.reset_index()
# Out:
#    index     Name   Age         City Gender              Email   Join Date
# 0      4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 1      0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2      6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 3      7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4      5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6      1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 7      3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8      8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2.reset_index(drop = True)
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 1    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
# df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 1    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df.sort_index()
# Out:
#       Name   Age         City Gender              Email   Join Date
# 0    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 1  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 2      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020
# 3  Charlie   NaN        Delhi      M    charlie@example  20-07-2021
# 4    David  22.0       Mumbai      M  david@example.com  12-11-2019
# 5      NaN  28.0        Delhi      F     eve@domain.com         NaN
# 6    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 7    Alice  25.0     New York      F  alice@example.com  01-05-2021
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021

# %%
df2["Rank"] = df2["Join Date"].rank()

# %% [markdown]
# ##

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date  Rank
# 0    David  22.0       Mumbai      M  david@example.com  12-11-2019   4.0
# 1    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021   2.0
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN   NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   5.0
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   7.0
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   7.0
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   7.0

# %%
df2["Rank"] = df2["Join Date"].rank(ascending = False, method ="dense")

# %%
df2
# Out:
#       Name   Age         City Gender              Email   Join Date  Rank
# 0    David  22.0       Mumbai      M  david@example.com  12-11-2019   3.0
# 1    Alice  25.0     New York      F  alice@example.com  01-05-2021   4.0
# 2    Alice  25.0     New York      F  alice@example.com  01-05-2021   4.0
# 3    Alice  25.0     New York      F  alice@example.com  01-05-2021   4.0
# 4      NaN  28.0        Delhi      F     eve@domain.com         NaN   NaN
# 5      Bob  30.0  Los Angeles      M    bob@example.com  15-06-2020   2.0
# 6  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   1.0
# 7  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   1.0
# 8  Charlie   NaN        Delhi      M    charlie@example  20-07-2021   1.0
