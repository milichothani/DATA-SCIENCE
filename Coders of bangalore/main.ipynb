# %%
with open("finaldata.txt" , encoding='utf-8') as f:
    data = f.read()

# %%
data
# Out:
# "techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes\n\nblrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes\n\nhsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com\n\ncloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud\n\nkoramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter\n\nai_bangalore_news\n1,340 posts\n38K followers\n200 following\nAI Bangalore\nMedia\n🤖 Daily AI news from India\n📢 Startup & resea
# ...

# %%
chunks = data.split("\n\n")
chunks = [c for c in chunks if len(c) > 3]
chunks
# Out:
# ['techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes',
#  'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes',
#  'hsr_startup_stories\n980 posts\n22.4K followers\n95 following\nStartup Stories HSR\nMedia\n🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com',
#  'cloud_dev_blr\n210 posts\n4,500 followers\n60 following\nNaveen DevOps\nEngineer\n☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud',
#  'koramangala_coffee_lover\n300 posts\n7,900 followers\n180 following\nSana B.\nCafe Explorer\n☕ Reviewing Bangalore’s hidden coffee spots\n📍 Koramangala\nyoutube.com/@sanacafehunter',
# ...

# %%
chunks[0]
# Out:
# 'techie_koramangala\n420 posts\n9,800 followers\n310 following\nArjun M.\nSoftware Engineer\n💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'

# %%
chunks[1]
# Out:
# 'blrcoder_girl\n150 posts\n6,300 followers\n120 following\nRiya Codes\nTech Creator\n👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'

# %%
chunks[10]
# Out:
# 'cubbonpark_runner\n95 posts\n1,500 followers\n40 following\nAman\nLifestyle\n🏃 Running after coding\n📍 Cubbon Park\nstrava.com/amanrunning'

# %%
def parse_chunk(chunk):
         chunk = chunk.strip()
         sep_chunk = chunk.split('\n')
         username = sep_chunk[0]
         no_of_posts = int(sep_chunk[1].split(" post")[0].replace(",", ""))
    
         no_of_followers = float(sep_chunk[2].split(" follower")[0].replace(",", "").replace("K", "").replace("M", ""))
         if("K" in sep_chunk[2]):
             no_of_followers = int(no_of_followers * 1000)
         elif("M" in sep_chunk[2]):
             no_of_followers = int(no_of_followers * 1000000)
         else:
             no_of_followers = int(no_of_followers)

         no_of_followings = float(sep_chunk[3].split(" following")[0].replace(",", "").replace("K", "").replace("M", ""))
         if("K" in sep_chunk[3]):
             no_of_followings = int(no_of_followings * 1000)
         elif("M" in sep_chunk[3]):
             no_of_followings = int(no_of_followings * 1000000)
         else:
             no_of_followings = int(no_of_followings)
        
         name = sep_chunk[4]

         if(len(sep_chunk)>5):
             type_of_page = sep_chunk[5]
             bio = "\n".join(sep_chunk[6:])
         else:
             type_of_page = "unknown"
             bio = ""
         # print(username, no_of_posts, no_of_followers, no_of_followings, name, type_of_page, bio, sep = "\n")
         return {"username": username, "no_of_posts": no_of_posts, "no_of_followers":no_of_followers, "no_of_followings": no_of_followings, "name": name, "type_of_page":type_of_page, "bio": bio}

        
#print(parse_chunk(chunks[0]))

# %%
all_chunks = []
for chunk in chunks:
    #print(f"The chunk is: {chunk}")
    parsed_chunk = parse_chunk(chunk)
    all_chunks.append(parsed_chunk)
print(all_chunks)
# Out:
# [{'username': 'techie_koramangala', 'no_of_posts': 420, 'no_of_followers': 9800, 'no_of_followings': 310, 'name': 'Arjun M.', 'type_of_page': 'Software Engineer', 'bio': '💻 Full-stack @ SaaS startup\n☕ Working from cafes in Koramangala\ngithub.com/arjunmakes'}, {'username': 'blrcoder_girl', 'no_of_posts': 150, 'no_of_followers': 6300, 'no_of_followings': 120, 'name': 'Riya Codes', 'type_of_page': 'Tech Creator', 'bio': '👩\u200d💻 Python | ML | Roadmaps\n🎥 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes'}, {'username': 'hsr_startup_stories', 'no_of_posts': 980, 'no_of_followers': 22400, 'no_of_followings': 95, 'name': 'Startup Stories HSR', 'type_of_page': 'Media', 'bio': '🚀 Interviews with Bangalore founders\n🎙️ Weekly startup breakdowns\nhsrstartupstories.com'}, {'username': 'cloud_dev_blr', 'no_of_posts': 210, 'no_of_followers': 4500, 'no_of_followings': 60, 'name': 'Naveen DevOps', 'type_of_page': 'Engineer', 'bio': '☁️ AWS | Docker | K8s\n📍 Sarjapur\ngithub.com/naveencloud'},
# ...

# %%
import json
s = json.dumps(all_chunks, indent = 4)
print(s)
# Out:
# [
#     {
#         "username": "techie_koramangala",
#         "no_of_posts": 420,
#         "no_of_followers": 9800,
#         "no_of_followings": 310,
#         "name": "Arjun M.",
#         "type_of_page": "Software Engineer",
#         "bio": "\ud83d\udcbb Full-stack @ SaaS startup\n\u2615 Working from cafes in Koramangala\ngithub.com/arjunmakes"
#     },
#     {
#         "username": "blrcoder_girl",
#         "no_of_posts": 150,
#         "no_of_followers": 6300,
#         "no_of_followings": 120,
#         "name": "Riya Codes",
#         "type_of_page": "Tech Creator",
#         "bio": "\ud83d\udc69\u200d\ud83d\udcbb Python | ML | Roadmaps\n\ud83c\udfa5 Coding Reels + Daily Motivation\nlinktr.ee/riyacodes"
#     },
#     {
#         "username": "hsr_startup_stories",
#         "no_of_posts": 980,
#         "no_of_followers": 22400,
#         "no_of_followings": 95,
#         "name": "Startup Stories HSR",
#         "type_of_page": "Media",
# ...

# %% [markdown]
# WHO HAS THE MAXIMUM POSTS?

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_posts']):
        max = chunk['no_of_posts']
        chunk_with_max_posts = chunk

# %%
print(chunk_with_max_posts)
# Out:
# {'username': 'startuphub_blr', 'no_of_posts': 2300, 'no_of_followers': 45000, 'no_of_followings': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}

# %% [markdown]
# WHO HAS MAXIMUM FOLLOWERS?

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_followers']):
        max = chunk['no_of_followers']
        chunk_with_max_followers = chunk

# %%
print(chunk_with_max_followers)
# Out:
# {'username': '_anujsinghal', 'no_of_posts': 1785, 'no_of_followers': 681000, 'no_of_followings': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %% [markdown]
# WHO HAS MAXIMUM FOLLOWINGS?

# %%
max = 0
for chunk in all_chunks:
    if(max < chunk['no_of_followings']):
        max = chunk['no_of_followings']
        chunk_with_max_followings = chunk

# %%
print(chunk_with_max_followings)
# Out:
# {'username': 'bangalore_tech_bro', 'no_of_posts': 402, 'no_of_followers': 12500, 'no_of_followings': 890, 'name': 'Rahul | HSR Hustler', 'type_of_page': 'Entrepreneur', 'bio': '🚀 Building the next Unicorn in Fintech\n☕ 3rd Wave Coffee addict\n💻 Python | React | AI\n📍 HSR Layout, BLR\nlinktr.ee/rahulbuilds'}

# %% [markdown]
# HOW MANY CATEGORIES?

# %%
categories = set()
for chunk in all_chunks:
    categories.add(chunk['type_of_page'])
print(categories, len(categories))
# Out:
# {'Cafe Nerd', 'Food & Drink', 'Blogger', 'Founder', 'Recruiter', 'Lifestyle', 'Investor', 'Public Figure', 'Design', 'Data Scientist', 'Engineer', 'Blog', 'Personal Blog', 'Software Engineer', 'Artist + Coder', 'Writer', 'Comedy', 'Developer', 'Tech', 'Data Science', 'Educator', 'Media', 'Education', 'Community', 'Cafe Explorer', 'Digital creator', 'Frontend Dev', 'Entrepreneur', 'Nonprofit organization', 'Full-stack Dev', 'Backend Developer', 'Coder', 'Tech Creator', 'Product Manager'} 34
