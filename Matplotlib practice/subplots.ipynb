# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4, 5, 12, 15, 18 ,19, 20, 16, 17]
y1=[i * 2 for i in x]
y2=[i ** 2 for i in x]

# %%
plt.subplot(1, 2, 1) #rows, cols, plot number
plt.plot(x, y1)
plt.title("Double of X")
plt.xlabel("Number")
plt.ylabel("Double of Number")

plt.subplot(1, 2, 2)
plt.plot(x, y2)
plt.title("Square of x")
plt.xlabel("Number")
plt.ylabel("Square of Number")

plt.tight_layout()
plt.show()

# %% [markdown]
# 2x2 GRID OF SUBPLOTS

# %%
y3=[i**0.5 for i in x]
y4=[10 - i for i in x]

plt.figure(figsize=(8, 6))
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title("x*2")

plt.subplot(2,2,2)
plt.plot(x, y2)
plt.title("x squared")

plt.subplot(2, 2, 3)
plt.plot(x, y2)
plt.title("sqrt(x)")

plt.subplot(2,2,4)
plt.plot(x, y4)
plt.title("10-x")

plt.tight_layout()
plt.show()

# %% [markdown]
# USING plt.subplots() FOR CLEAN CODE

# %%
fig, axs=plt.subplots(1, 2, figsize=(10,4))
axs[0].plot(x, y1)
axs[0].set_title("x*2")

axs[1].plot(x, y2)
axs[1].set_title("x**2")

fig.suptitle("Comparision Plot" ,fontsize=14) #sup = superplot
plt.show()

# %% [markdown]
# LOOPING OVER SUBPLOTS

# %%
fig, axs = plt.subplots(2, 2, figsize=(8, 6))
ys = [y1, y2, y3, y4]
titles = ['x*2', 'x squared', 'sqrt(x)', '10-x']

for i in range(2):
    for j in range(2):
        idx = i*2+j
        axs[i,j].plot(x,ys[idx])
        axs[i,j].set_title(titles[idx])

plt.tight_layout()
plt.show()
